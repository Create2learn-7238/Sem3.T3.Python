# %% [markdown]
# # WAP to append ,delete and dispplay element of a list using class

# %%
class list2:
    def __init__(self,l1):
        self.l1=l1
    def append(self,l2):
        self.l1.append(l2)
    def delete(self,r):
        self.l1.remove(r)
    def display(self):
        print(self.l1)

# %%
l=list2([1,2,3])
while True:
    print("*******************************")
    print("Enter 1 to append")
    print("Enter 2 to delete")
    print("Enter 3 to display")
    print("Enter 0 to Exit ...")
    a=int(input("Enter your choice : "))
    if a==0:
        print("Exiting...")
        break
    elif a==1:
        a=int(input("Enter number to append : "))
        l.append(a)
    elif a==2:
        a=int(input("Enter number to delete : "))
        try :
            l.remove(a)
        except Exception as e:
            print("Error :", e)
    elif a==3:
        l.display()
    else :
        print("Invalid choice")
# Out:
# *******************************
# Enter 1 to append
# Enter 2 to delete
# Enter 3 to display
# Enter 0 to Exit ...
# Enter your choice : 1
# Enter number to append : 2
# *******************************
# Enter 1 to append
# Enter 2 to delete
# Enter 3 to display
# Enter 0 to Exit ...
# Enter your choice : 3
# [1, 2, 3, 2]
# *******************************
# Enter 1 to append
# Enter 2 to delete
# Enter 3 to display
# Enter 0 to Exit ...
# Enter your choice : 2
# Enter number to delete : 22
# Error : 'list2' object has no attribute 'remove'
# *******************************
# Enter 1 to append
# Enter 2 to delete
# Enter 3 to display
# Enter 0 to Exit ...
# Enter your choice : 11
# Invalid choice
# *******************************
# Enter 1 to append
# Enter 2 to delete
# Enter 3 to display
# Enter 0 to Exit ...
# Enter your choice : 2
# Enter number to delete : 3
# Error : 'list2' object has no attribute 'remove'
# *******************************
# Enter 1 to append
# ...

# %% [markdown]
# ### WAP to create class atm and make methode to create pin change pin , check balance and widhraw and menu

# %% [markdown]
# # ATM

# %%
class atm:
    def __init__(self):
        self.bal=10000
    def createpin(self):
        pin = int(input("Enter 4 digit pin :"))
        if len(str(pin))==4:
            self.pin=pin
        else :
            print("Invalid enter 4 digit only")
        self.menu()
    def menu(self):
        print("********************************************")
        print("Choice :")
        print("1.Change pin")
        print("2.Widhraw")
        print("3.Check balance")
        print("0.Exit")
    def changepin(self):
        oldpin=int(input("Enter old Pin :"))
        if self.pin==oldpin :
            newpin=int(input("Enter New Pin :"))
            self.pin=newpin
        else : 
            print("Invalid Pin")
        self.menu()
    def checkbal(self):
        epin=int(input("Enter your Pin :"))
        if self.pin==epin :
            print(self.bal)
        self.menu()
    def widhraw(self):
        epin=int(input("Enter your Pin :"))
        if self.pin==epin :
            wid=int(input("Enter amt to widhraw :"))
            if wid<self.bal-2000 :
                self.bal=self.bal-wid
                print("Succeful widraw")
            else :
                print("No Balance")
        else :
            print("Invalid Pin")
        self.menu()

# %%
a=atm()
c=1
a.createpin()
while c!=0:
    c=int(input("Enter your choice "))
    if c==1:
        a.changepin()
    elif c==2:
        a.widhraw()
    elif c==3:
        a.checkbal()
    elif c==0:
        print("Exiting...")
    else :
        print("Invalid")
# Out:
# Enter 4 digit pin :1234
# ********************************************
# Choice :
# 1.Change pin
# 2.Widhraw
# 3.Check balance
# 0.Exit
# Enter your choice 1
# Enter old Pin :1234
# Enter New Pin :2580
# ********************************************
# Choice :
# 1.Change pin
# 2.Widhraw
# 3.Check balance
# 0.Exit
# Enter your choice 2
# Enter your Pin :2580
# Enter amt to widhraw :2000
# Succeful widraw
# ********************************************
# Choice :
# 1.Change pin
# 2.Widhraw
# 3.Check balance
# 0.Exit
# Enter your choice 3
# Enter your Pin :2580
# 8000
# ********************************************
# Choice :
# 1.Change pin
# 2.Widhraw
# 3.Check balance
# 0.Exit
# Enter your choice 2
# Enter your Pin :2580
# Enter amt to widhraw :4532
# Succeful widraw
# ********************************************
# Choice :
# 1.Change pin
# 2.Widhraw
# 3.Check balance
# 0.Exit
# Enter your choice 3
# Enter your Pin :2580
# 3468
# ********************************************
# Choice :
# ...

# %% [markdown]
# # PIZZA

# %%
class pizza :
    def __init__(self):
        self.total=0
    def size (self , s):
        r=0
        if s==1:
            r=50
        elif s==2:
            r=100
        elif s==3:
            r==200
        else : print("Invalid")
        self.total+=r
    def topping(self):
        print("Menu : 1.corn , 2.tomato , 3.capcicum , 4.onion - 20 each")
        print("5.Brocolli , 6.Mushroom , 7.olive - 50 each")
        n=int(input("Enter number of topings"))
        for i in range(n):
            a=int(input("Enter choice of toping"))
            if a in [1,2,3,4]:
                self.total+=20
            elif a in [5,6,7]:
                self.total+=50
            else : 
                print("Invalid toppings")            
    def chezz(self,r):
        print("Menu : 1.Moza , 2.feta , 3.chheda  - 50 each")
        n=int(input("Enter number of chezze"))
        for i in range(n):
            a=int(input("Enter choice of chezz"))
            self.total+=50
    def totaaal(self):
        print(self.total)

# %%
u=pizza()
print("""
      1.small
      2.midium
      3.large   
      """)
s=int(input("Enter size  ; "))
u.size(s)
u.topping()
u.chezz(5)
u.totaaal()
# Out:
#       1.small
#       2.midium
#       3.large
#
# Enter size1
# Menu : 1.corn , 2.tomato , 3.capcicum , 4.onion - 20 each
# 5.Brocolli , 6.Mushroom , 7.olive - 50 each
# Enter number of topings1
# Enter choice of toping1
# Menu : 1.Moza , 2.feta , 3.chheda  - 50 each
# Enter number of chezze1
# Enter choice of chezz11
# 120

# %%
# sir no code 
class Pizza:
    def __init__(self, size, toppings, cheese):
        self.size = size
        self.toppings = toppings
        self.cheese = cheese
        
    def price(self):
        self.cost = 0
        if self.size == 'small':
            self.cost += 50
        elif self.size == 'medium':
            self.cost += 100
        else:
            self.cost += 200
        topping_prices_20 = ['corn', 'tomato', 'onion', 'capsicum']
        topping_prices_50 = ['mushroom', 'olives', 'broccoli']
        for topping in self.toppings:
            if topping in topping_prices_20:
                self.cost += 20
            else:
                self.cost += 50
        #for cheese
        self.cost += 50 * len(self.cheese)
        return self.cost

class Order:
    def __init__(self, name, customerid):
        self.name = name
        self.customerid = customerid

    def order(self, n):
        self.pizzas = [] 
        for i in range(n):
            toppings = []
            cheese = []
            print('Customize Pizza',i+1)
            size = input('Select size(small/medium/large): ')
            t = int(input('How many toppings(number): '))
            for i in range(t):
                toppings.append(input('Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): '))
            t = int(input('How many type of cheese(number): '))
            for i in range(t):
                cheese.append(input('Enter cheese(mozarella,feta,cheddar): '))
            self.pizzas.append(Pizza(size, toppings, cheese))

    def bill(self):
        self.total = 0
        count = 1
        for p in self.pizzas:
            print('Pizza', count)
            print("Size:",p.size)
            print("Toppings:",p.toppings)
            print("Cheese:",p.cheese)
            self.total += p.price()
            count += 1
        print('Total bill amount:', self.total)
        
number=int(input("How many pizzas you want to order: "))
order1 = Order('Tejas', 1)
order1.order(number)
order1.bill()
# Out:
# How many pizzas you want to order: 2
# Customize Pizza 1
# Select size(small/medium/large): small
# How many toppings(number): 5
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): corn
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): tomato
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): onion
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): corn
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): rror
# How many type of cheese(number): 1
# Enter cheese(mozarella,feta,cheddar): feta
# Customize Pizza 2
# Select size(small/medium/large): 1
# How many toppings(number): 1
# Enter toppings(corn,tomato,onion,capsicum,mushroom,olives,brocolli): corn
# How many type of cheese(number): 0
# Pizza 1
# Size: small
# Toppings: ['corn', 'tomato', 'onion', 'corn', 'rror']
# Cheese: ['feta']
# Pizza 2
# Size: 1
# Toppings: ['corn']
# Cheese: []
# Total bill amount: 450
