# %%
import math
print(math.log10(10000))
import math as m
print(m.pi)
from math import *
print(sqrt(15))
# Out:
# 4.0
# 3.141592653589793
# 3.872983346207417

# %% [markdown]
# ## Python os Module
# - 1) handling current working directory

# %%
import os
print(os.getcwd())
#cwd - Current working directory
#pwd - present "               "
# Out:
# C:\Users\LJENG\Dixit Patel T3 B2 56

# %% [markdown]
# - 2) change the current working directory

# %%
import os
print(os.getcwd())
os.chdir("D://DP")
print(os.getcwd())
# Out:
# C:\Users\LJENG\Dixit Patel T3 B2 56
# D:\DP

# %% [markdown]
# - 3) creating a direectory

# %%
import os
os.mkdir("D://DP//python")
print("Done once ")
# Out:
# Done once

# %%
# AS already exists
import os
os.mkdir("D://DP//python")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-18-edbf07576577> in <module>
#       1 import os
# ----> 2 os.mkdir("D://DP//python")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'D://DP//python'

# %%
import os
os.mkdir("D://DP11111//python")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-b00f6c6c0ef6> in <module>
#       1 import os
# ----> 2 os.mkdir("D://DP11111//python")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D://DP11111//python'

# %% [markdown]
# - 4) listing out files and dir.

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'ai.txt', 'Another.txt', 'capital.txt', 'Code-without-coment.txt', 'code.txt', 'demo.txt', 'Details.txt', 'f1.txt', 'f2.txt', 'f3.txt', 'oddindexline.txt', 'oddline.txt', 'One file to another.ipynb', 'One.txt', 'replace.txt', 'RevAnother.txt', 'reverse.txt', 'student name.txt', 'test.txt', 'U-6 working with files.ipynb', 'U-7 Modules and directories.ipynb', 'user.txt']

# %% [markdown]
# - 5) delete files and dir.

# %%
import random as r
print(int(r.random()*10))
# Out:
# 1

# %% [markdown]
# # Module
# - python module is a file containing python defination and statement
# - module can define function classes and varibale
# - it makes the code logically organised

# %%
# %%writefile calc.py
def add(a,b):
    print("Sum : ",a+b)
def sub(a,b):
    print("Subtractin : ",a-b)
def mul(a,b):
    print("Multiplication : ",a*b)
def div(a,b):
    print("Division : ",a/b)
def floor(a,b):
    print("Floor-Div : ",a//b)
def power(a,b):
    print("Power : ",a**b)
def modulo(a,b):
    print("Power : ",a%b)
# Out:
# Overwriting calc.py

# %%
import calc as c
print(c)
c.add(2,3)
c.sub(2,3)
c.mul(2,3)
c.div(2,3)
c.floor(2,3)
c.power(2,3)
c.modulo(2,3)
# Out:
# <module 'calc' from 'C:\\Users\\LJENG\\Dixit Patel T3 B2 56\\calc.py'>
# Sum :  5
# Subtractin :  -1
# Multiplication :  6
# Division :  0.6666666666666666
# Floor-Div :  0
# Power :  8
# Power :  2

# %%
import calc 
dir(calc)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'div',
#  'floor',
#  'modulo',
#  'mul',
#  'power',
#  'sub']

# %%
from calc import add
calc.sub(5,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e2252251d72> in <module>
#       1 from calc import add
# ----> 2 calc.sub(5,5)
#
# NameError: name 'calc' is not defined

# %%
# %%writefile myfunc.py
def mystring(a):
    print("Len :",len(a))
    print("Upper :",a.upper())
    print("Lower :",a.lower())
    print("Title :",a.title())
    print("Capitalize :",a.capitalize())
    print("isalpha :",a.isalpha())
    print("isalumun :",a.isalnum())
    print("istitle :",a.istitle())
    print("isdigit :",a.isdigit())
    
def mylist(a):
    print("Len :",len(a))
    a.append(100)
    print("append 2 :",a)
    a.extend([7,8,9])
    print("extend 789 :",a)
    a.sort()
    print("sort :",a)
    a.reverse()
    print("Reverse :",a)
# Out:
# Overwriting myfunc.py

# %%
import myfunc as m
m.mystring("Python is easy to learn")
print("**************************")
m.mylist([1,2,3])
# Out:
# Len : 23
# Upper : PYTHON IS EASY TO LEARN
# Lower : python is easy to learn
# Title : Python Is Easy To Learn
# Capitalize : Python is easy to learn
# isalpha : False
# isalumun : False
# istitle : False
# isdigit : False
# **************************
# Len : 3
# append 2 : [1, 2, 3, 100]
# extend 789 : [1, 2, 3, 100, 7, 8, 9]
# sort : [1, 2, 3, 7, 8, 9, 100]
# Reverse : [100, 9, 8, 7, 3, 2, 1]

# %% [markdown]
# ## imp checking
# - type(a)==str or type(a)==list no double qotes

# %%
from datetime import *
today=date.today()
print(today)
d=date(2025,11,13)
print(d)
print()
noon=time(12,10,25)
print(noon)
noon=time(23,10,25)
print(noon)
print()
now=datetime.now()
print(now)
# Out:
# 2025-12-03
# 2025-11-13
#
# 12:10:25
# 23:10:25
#
# 2025-12-03 12:38:58.681233

# %% [markdown]
# ### import pkg.calc
# ### import pkg.subpkg.myfunc
